# %% [markdown]
# # **1. 머신러닝(Machine Learning)**

# %% [markdown]
# * 인공지능: 인공(Artificail) + 지능(Intelligence)
#  - 과거 로봇청소기, 과거 일반적인 게임(학습을 하지 않음)
# * 머신러닝: 학습(Learning)하는 기계(Machine).
#  - Decision tree, SVM
# * 딥러닝: 깊은(deep) 신경망 구조의 머신러닝
#  - MLP, CNN, RNN, Transformar

# %% [markdown]
# ### 1-1. 배경

# %% [markdown]
# * 과거 컴퓨터로 데이터를 읽어 들이고 그 데이터 안에서 특징을 학습해서 패턴을 찾아내는 작업을 해 왔음(패턴 인식)
# * 데이터를 대량으로 수집 처리할 수 있는 환경이 갖춰짐으로 할 수 있는 일이 많아짐
#
# > 머신러닝은 데이터로부터 특징이나 패턴을 찾아내는 것이기 때문에 데이터가 가장 중요함

# %% [markdown]
# ### 1-2. 정의
# * 기계학습 또는 머신러닝은 인공지능의 한 분야로, 컴퓨터가 학습할 수 있도록 하는 알고리즘과 기술을 개발하는 분야
# * 무엇(x)으로 무엇(y)을 예측하고 싶다
#  - y = f(x)
#  - f: 모형(머신러닝 알고리즘), x: 입력변수(독립변수), y: 출력변수(종속변수)
# * 주어진 데이터를 통해서 입력변수와 출력변수간의 관계를 만드는 함수 f를 만드는 것

# %% [markdown]
# # 2. 머신러닝으로 할 수 있는 것

# %% [markdown]
# ### 2-1. 회귀(Regreesion)
# * 시계열(시각적인 변화를 연속적으로 관측한 데이터) 같은 연속된 데이터를 취급할 때 사용하는 기법
# * 과거 주식 추레를 학습해서 내일의 주가를 예측하는 시스템

# %% [markdown]
# ### 2-2. 분류(Classification)
# * 주어진 데이터를 클래스 별로 구별해 내는 과정으로 데이터와 데이터의 레이블 값을 학습시키고 어느 범주에 속한 데이터인지 판단하고 예측하는 기법
# * 스팸 메일인지 아니닞 구별해주는 시스템
# * 숫자 손글씨 데이터를 통해 숫자 이미지 분류 모델

# %% [markdown]
# ### 2-3. 클러스터링(Clustering)
# * 분류와 비슷하지만 데이터에 레이블(정답 데이터)이 없음
# * 유사한 속성들을 갖는 데이터를 일정한 수의 군집으로 그룹핑하는 비지도 학습
# * SNS 데이터를 통해 소셜 및 사회 이슈를 파악

# %% [markdown]
# # 3. 학습

# %% [markdown]
# ### 3-1. 지도학습
# * y = f(x)에 대하여 입력 변수(x)와 출력 변수(y)의 관계를 모델링하는 것
# * y에 대하여 예측 또는 분류하는 문제
# * 레이블이 주어짐

# %% [markdown]
# ### 3-2. 비지도 학습
# * 출력 변수(y)가 존재하지 않고, 입력 변수(x)간의 관계에 대해 모델링 하는 것
# * 군집 분석: 유사한 데이터끼리 그룹화
# * PCA: 독립 변수들의 차원을 축소화

# %% [markdown]
# ### 3-3. 강화 학습
# * 수 많은 시뮬레이션을 통해 현재의 선택이 먼 미래의 보상이 최대가 되도록 학습
# * Agent가 action을 취하고 환경에서 보상을 받고 이 보상이 최대가 되도록 최적의 action을 취하는 방법을 배움

# %% [markdown]
# # **4. 머신러닝의 종류**

# %% [markdown]
# ### 4-1. 선형회귀분석
# * '독립변수와 종속변수가 선형적이 관계가 있다'라는 가정하에 분석
# * 직선을 통해 종속변수를 예측하기 때문에 독립변수의 중요도와 영향력을 파악하기 쉬움

# %% [markdown]
# ### 4-2. 의사결정나무
# * 독립변수의 조건에 따라 종속변수를 분리
# * 이해하기 쉬우나 overfitting이 잘 일어남

# %% [markdown]
# ### 4-3. KNN
# * 새로 들어온 데이터의 주변 k개의 데이터로 class를 분류하는 기법

# %% [markdown]
# ### 4-4. Neural Network
# * 입력, 은닉, 출력층으로 구성된 모형으로서 각 층을 연결하는 노드의 가중치를 업데이트하면서 학습

# %% [markdown]
# ### 4-5. SVM
# * class간의 거리가 최대가 되도록 decision boundary를 만드는 방법

# %% [markdown]
# ### 4-6. Ensemble Learning
# * 여러 개의 모델을 결합하여 사용하는 모델

# %% [markdown]
# ### 4-7. K-means clustring
# * 레이블없이 데이터의 군집으로 k개를 생성

# %% [markdown]
# # **5. 데이터 분석과정**

# %% [markdown]
# * raw 데이터 -> 전처리 된 데이터 -> 실험설계 -> 모델
# * 모델의 성능을 높이려면 데이터를 잘 만들어야 함(목적에 맞게 합리적으로 만듦)
